# %%
import pandas as pd

# Load your dataset (update filename if needed)
df = pd.read_csv("mode_imputed_patient_features_db2.csv")

# Drop the 'Finger_dist' column
df.drop(columns=['Finger_dist'], inplace=True)

# Save the updated dataset
df.to_csv("mode_imputed_patient_features_no_fing_db2.csv", index=False)

# Confirm it's removed
print("Column 'Finger_dist' has been removed.")
df.head()
# Out:
# Column 'Finger_dist' has been removed.
#    patient_id   Age  Height  Weight Gender  CF_dist      fs      RR_mean  \
# 0          34  17.0   172.0    60.0      M     65.0  1000.0   994.783333
# 1          35  26.0   159.0    57.0      F     55.0  1000.0   863.678832
# 2          36  61.0   179.0    71.0      M     65.0  1000.0  1366.790698
# 3          37  61.0   179.0    71.0      M     65.0  1000.0  1147.019417
# 4          38  40.0   154.0    69.0      F     57.0  1000.0   793.046667
#
#        RR_std  RR_min  ...   AK_skew  AK_kurtosis  AK_count    AK_iqr  \
# 0  113.171557   742.0  ...  0.406720     0.415487       117  0.030140
# 1   42.149931   776.0  ... -0.059284    -0.535529       134  0.018446
# 2   27.108113  1316.0  ...  0.165937     0.391604        83  0.029150
# 3   89.629847   990.0  ... -0.383708     0.422909       101  0.048350
# 4   32.276560   690.0  ... -0.423272     0.054012       147  0.015323
#
# ...
